# %% [markdown]
# ***Plotly and Cufflinks***

# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 6.0.1

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)  # Connects JavaScript to the Notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
cf.go_offline()  # Allows us to use Cufflinks offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
# DATA
my_dataFrame_1 = pd.DataFrame(np.random.randn(100, 4), columns = 'A B C D'.split())
my_dataFrame_1.head()
# Out:
#           A         B         C         D
# 0  1.433192 -0.607743  0.844445  1.268851
# 1 -0.687655 -0.986466  0.629188  0.712319
# 2 -1.504460 -1.091033  1.301998 -1.094087
# 3  0.429353 -1.438653 -0.009317  2.513527
# 4 -1.082660 -0.348240  0.882352  0.608401

# %%
my_dataFrame_2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32, 43, 50]})
my_dataFrame_2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
my_dataFrame_1.plot()  # Plots with Matplotlib

# %%
import chart_studio.plotly as py
pd.options.plotting.backend = 'plotly'
from chart_studio.plotly import plot

# Don't use iplot, use .plot instead (iplot is old)

# my_dataFrame_1.plot()  # Plots with Plotly
# Now it's a mouseover interactive so I can mouseover for specific values
# and zoom in/out by click-dragging a rectangle to how I want to zoom-in
# show/hide certain line graphs by clicking on them in the legend
# and more options too.)

# %%
my_dataFrame_1.plot(kind = 'scatter', x = 'A', y = 'B', s = 20) #.update_traces(marker=dict(size = 20))

# my_dataFrame_1.plot(kind = 'scatter', x = 'A', y = 'B').update_traces(marker=dict(size = 20))

## mode = 'markers'  #<- Does not work here as a parameter. For scatter plot, now Plotly automatically shows the data as dots/markers

# %%
iplot(my_dataFrame_1)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 iplot(my_dataFrame_1)
#
# File ~/miniconda3/envs/navigator/lib/python3.11/site-packages/plotly/offline/offline.py:379, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     376 config.setdefault("linkText", link_text)
#     378 # Get figure
# --> 379 figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     381 # Handle image request
#     382 post_script = build_save_image_post_script(
#     383     image, filename, image_height, image_width, "iplot"
#     384 )
#
# File ~/miniconda3/envs/navigator/lib/python3.11/site-packages/plotly/tools.py:535, in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     533     validated = True
#     534 else:
# --> 535     raise exceptions.PlotlyError(
#     536         "The `figure_or_data` positional "
#     537         "argument must be "
#     538         "`dict`-like, `list`-like, or an instance of plotly.graph_objs.Figure"
#     539     )
#     541 if validate_figure and not validated:
#     543     try:
#
# PlotlyError: The `figure_or_data` positional argument must be `dict`-like, `list`-like, or an instance of plotly.graph_objs.Figure
