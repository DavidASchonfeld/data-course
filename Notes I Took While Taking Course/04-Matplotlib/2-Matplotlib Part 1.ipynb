# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as py

# %%
fig1 = plt.figure()
axes1a = fig1.add_axes([0.1, 0.1, 0.8, 0.8])
axes1b = fig1.add_axes([0.8, 0.15, 0.4, 0.3])
plt.show()

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2  # (aka y to the power of 2)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])
