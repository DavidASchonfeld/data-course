# %%
print("This is a Code Cell. Press the \">\" button above to run the code cell you are currently in.")
# Out:
# This is a Code Cell. Press the ">" button above to run the code cell you are currently in.

# %%
print("Shift+Enter: Run current code cell")
# Out:
# Shift+Enter: Run current code cell

# %%
print("Alt+Enter: Insert code cell directly under current code cell.")
# Out:
# Alt+Enter: Insert code cell directly under current code cell.

# %%
print("Yes, you can export this as an HMTL, Python, etc.")
# Out:
# Yes, you can export this as an HMTL, Python, etc.

# %%
print("If your code cell is stuck in an infinite loop, Python crashing etc., go to \"Kernel\" -> \"Restart\" ")
# Out:
# If your code cell is stuck in an infinite loop, Python crashing etc., go to "Kernel" -> "Restart"

# %%
print("\"Help\" -> \"Keyboard Shortcuts\" to see the other keyboard shortcuts")
# Out:
# "Help" -> "Keyboard Shortcuts" to see the other keyboard shortcuts

# %%
print("In the assignments, it will have \"In [X]\" to show input and Out[X] (He uses Out[X] to write: this is the output that we want you to have. Fill in the code in the \"In\" section to get this output stuff). If you run your code, it will automatically overwriute the Out[X}")
# Out:
# In the assignments, it will have "In [X]" to show input and Out[X] (He uses Out[X] to write: this is the output that we want you to have. Fill in the code in the "In" section to get this output stuff). If you run your code, it will automatically overwriute the Out[X}

# %% [markdown]
# Markdown Option = Text Option. Not Code. So I can type text here. If I type code here by accident, it won't be run.

# %% [markdown]
# What you can do. In the instructions Markdown box, type "Alt+Enter" and you can then type in code to test without messing up the Out[X] part where he had already saved the answers he wants us to aim towards.

# %%
print("\"Shift + Tab\" inside a cell, while the text cursor is on a method name, to see a description for that method, including its parameters, and what the parameters are for etc.")
# Out:
# "Shift + Tab" inside a cell, while the text cursor is on a method name, to see a description for that method, including its parameters, and what the parameters are for etc.

# %%
print("In Short: \"Shift+Tab\": Method Explanation")
# Out:
# In Short: "Shift+Tab": Method Explanation
